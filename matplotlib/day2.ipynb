# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x_1 = np.linspace(0, 5, 10)#linespace[start, end, num] Returns an array of numbers between start and end with num being the number of outputs to be shown (default 50)
y_1 = x_1**2
plt.plot(x_1, y_1)
plt.title("Distribution of X and Y")
plt.xlabel("X values")
plt.ylabel("Y values")
# Out:
# Text(0, 0.5, 'Y values')

# %%
#Sub Plot
plt.subplot(1,2,1)
plt.plot(x_1,y_1,'r')
plt.subplot(1,2,2)
plt.plot(x_1,y_1,'g')

# %%
#Figure
fig_1 = plt.figure(figsize=(5,4), dpi=100)
axes_1 = fig_1.add_axes([0.1, 0.1, 0.9, 0.9]) #add_axes(left, bottom, width, height)
axes_1.set_xlabel('Days')
axes_1.set_ylabel('Days squared')
axes_1.set_title("Days Squared Chart")
axes_1.plot(x_1,y_1,label='x/x^2')
axes_1.plot(y_1, x_1, label='x^2/x')
axes_1.legend(loc=0)
#Instead of loc=0, we can use Upper left:1, Upper right:2, Lower left:3, Lower Right:4
#Now let's try adding another plot inside this figure

axes_2 = fig_1.add_axes([0.45, 0.45, 0.4, 0.3])
axes_2.set_ylabel('Days squared')
axes_2.set_title("Days Squared Chart")
axes_2.plot(x_1,y_1,'g')

axes_1.text(0, 20, 'Message 1')
axes_2.text(0, 40, 'Message 2')
# Out:
# Text(0, 40, 'Message 2')
